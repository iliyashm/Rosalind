# %%
def string_to_strings(argument):
    switcher = {
        "A": "T",
        "C": "G",
        "G": "C",
        "T": "A"
    }
 
    return switcher.get(argument, "nothing")

s = "..."
new_s = ""
for ch in s:
    new_s += string_to_strings(ch)
new_s = new_s[::-1]
new_s
# Out:
# '...'
